# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
fig, ax=plt.subplots(figsize=(4, 3))
ax.plot([1, 2, 3, 4], [10, 2, 9, 3], marker='D')
# Out:
# <img src="data:image/png;base64,..." width="400">
